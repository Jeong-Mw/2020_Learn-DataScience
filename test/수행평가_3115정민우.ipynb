# %% [markdown]
# ### 필요한 라이브러리 불러오기

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %% [markdown]
# ### url 변수에 크롤링할 홈페이지 주소 가져오기

# %%
url = "http://www.lotteria.com/menu/Menu_All.asp"

# %% [markdown]
# ### 해당 url의 html을 불러오기 + HTML 분석하고 파싱

# %%
html = urlopen(url)
soup = BeautifulSoup(html, 'html.parser')

soup
# Out:
# <!DOCTYPE HTML>
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>롯데리아</title>
# <link href="/library/css/style_yg.css" rel="stylesheet" type="text/css"/>
# <!-- $$$ -->
# <!-- <meta http-equiv="X-UA-Compatible" content="IE=9" /> -->
# <meta content="IE=Edge" http-equiv="X-UA-Compatible">
# <link href="/Images/common/favicon.png" id="shortcut" rel="shortcut icon"/>
# <link href="/library/css/reset.css" rel="stylesheet" type="text/css">
# <link href="/library/css/common.css" rel="stylesheet" type="text/css"/>
# <link href="/library/css/select.css" rel="stylesheet" type="text/css"/>
# <link href="/library/css/style.css" rel="stylesheet" type="text/css"/>
# <link href="/library/css/jquery.ui.theme.css" rel="stylesheet" type="text/css"/>
# <link href="/library/css/jquery.ui.datepicker.css" rel="stylesheet" type="text/css"/><script src="/library/js/jquery-1.5.1.min.js" type="text/javascript"></script>
# <script src="/library/js/plugin/jquery.ui.core.js" type="text/javascript"></script>
# <script src="/library/js/plugin/jquery.ui.datepicker.js" type="text/javascript"></script>
# <script src="/library/js/plugin/jquery.ui.datepicker-ko.js" type="text/javascript"></script>
# <script src="/library/editor/SE/js/HuskyEZCreator.js" type="text/javascript"></script>
# <script src="/library/js/function.js" type="text/javascript"></script>
# <script src="/library/js/file.style.js" type="text/javascript"></script>
# <script src="/library/js/iePngFix.js" type="text/javascript"></script>
# <script src="/library/js/swfobject.js" type="text/javascript"></script>
# <script src="/library/js/ui.js" type="text/javascript"></script>
# <script src="/library/js/jquery.func.js" type="text/javascript"></script>
# <script type="text/javascript">
# 	$(document).ready(function () {
#
# 	});
#
# 	var goView			= function (strValue, cint2Val) { // 제품상세로 이동
# 		$("#frmNavi input[name='Idx']").val(strValue);
# 		$("#frmNavi input[name=C2]").val(cint2Val);
# 		$("#frmNavi").attr("action", "Menu_View.asp").submit();
# 	}
#
# 	var setCategorySub	= function (strValue) { // 제품카테고리 선택시
# 	$("#frmNavi input[name='Idx']").val("");
# 		$("#frmNavi").submit();
# 	}
#
# 	var goC2	= function (strValue) { // 제품카테고리 선택시
# 		$("#frmNavi input[name='Idx']").val("");
# 		$("#frmNavi input[name='C2']").val(strValue);
# 		$("#frmNavi").submit();
# 	}
# 	var setSearch	= function(strValue){ // 제품검색
# 		$("#frmNavi").submit();
# 	}
# //	$('.searchBtn').live('click', function(e){
# //		$("#frmNavi").submit();
# //	}
#
# </script>
# </link></meta></head>
# <body class="sub" onload="uiRefresh();" onresize="uiRefresh();">
# <!-- skip navigation -->
# <a class="skipNaviBtn" href="#content">본문 바로가기</a>
# <!-- <div id="menupanwrapper"> --><!-- 매장찾기쪽에선 안나옴 -->
# <!-- <div class="closeBtn"><a href="#" onclick="closeMenuPan();return false;"><img src="/Images/menu/btn_close.gif" onMouseOver=this.src="/Images/menu/btn_close_on.gif" onMouseOut=this.src="/Images/menu/btn_close.gif"></a></div>
# </div> -->
# <!-- header -->
# <div class="gnbNavi" id="header">
# <div id="gnb">
# <h1 style="position:absolute;z-index:4;top:40px;"><a href="/index.asp"><img alt="LOTTERIA" src="/Images/top/logo1.gif"/></a></h1>
# <div class="gnb_list">
# <ul>
# <li><a href="/Affiliate/Advantage.asp"><img alt="가맹점모집" src="/Images/top/btn_gnb_francise.gif"/></a></li>
# <li><a href="/VOC/Voc_Write.asp"><img alt="고객의소리" src="/Images/top/btn_gnb_customer.gif"/></a></li>
# <!-- <li><a href="/Campaign/Management/Ethics_pop.asp" target="_blank" title="새창으로 열기"><img src="/Images/top/btn_gnb_sinmun.gif" alt="신문고"></a></li><!-- 2013-09-10 수정 -->
# <li><a href="/Campaign/Management/Ethics_report.asp" target="_blank" title="새창으로 열기"><img alt="윤리경영" src="/Images/top/btn_gnb_ethics.gif"/></a></li>
# <li><a href="/etc/sitemap.asp"><img alt="사이트맵" src="/Images/top/btn_gnb_sitemap.gif"/></a></li>
# <li><a href="http://www.lotteria.com/eng/main.asp"><img alt="English" src="/Images/top/btn_gnb_english.gif"/></a></li>
# </ul>
# </div>
# <div class="popup_grade" style="display:none;">
# <!-- 			<img src="/Images/top/img_grade.jpg" alt="L.Point 회원등급 안내"> -->
# <div> <!-- class="hidden_tx" -->
# <h2><img alt="L.POINT 회원 등급 안내" src="/Images/top/img_tit_popup_level.jpg"/></h2>
# <ul class="grade_info">
# <li><p>우수회원 산정 기준 : 연 12회 이상 L.POINT 적립</p></li>
# <li><p>L.POINT 취소, 환불 및 사용한 건은 반영되지 않습니다.</p></li>
# <li><p>회원 등급은 1년간 유지 됩니다.</p></li>
# <li><p>등급 산정은 매년 3월 1일부터 적용 됩니다.</p>
# <p class="bgnone">ex) 15년 실적 기준 → 16년 3월 1일 ~ 17년 2월 28일 등급 적용</p></li>
# <li><p>롯데리아/엔제리너스 쇼핑몰, 홈서비스는 등급제 적용이 불가하며, </p><p class="bgnone">일괄 0.3% 적립됩니다.</p></li>
# <li><p>등급별 혜택</p>
# <table class="grade_benefit" summary="L.POINT 등급별 혜택을 안내합니다.">
# <caption>L.POINT 등급별 혜택</caption>
# <colgroup>
# <col width="50%"/>
# <col width="*"/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">구분</th>
# <th scrop="col">헤택</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>우수회원</td>
# <td>결제금액의 0.5% 적립</td>
# </tr>
# <tr>
# <td>일반회원</td>
# <td>결제금액의 0.3% 적립</td>
# </tr>
# </tbody>
# </table>
# </li>
# <!-- 2016-03-31 브랜드별 등급표 추가 -->
# <li><p>롯데리아 브랜드별 등급</p>
# <table class="grade_benefit" summary="롯데리아 브랜드별 등급을 안내합니다.">
# <caption>롯데리아 브랜드별 등급 안내</caption>
# <colgroup>
# <col width="50%"/>
# <col width="*"/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">브랜드</th>
# <th scrop="col">등급</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>롯데리아</td>
# <td>
# </td>
# </tr>
# <tr>
# <td>엔제리너스</td>
# <td>
# </td>
# </tr>
# <tr>
# <td>TGI Fridays</td>
# <td>
# </td>
# </tr>
# <tr>
# <td>크리스피크림 도넛</td>
# <td>
# </td>
# </tr>
# <tr>
# <td>빌라드샬롯</td>
# <td>
# </td>
# </tr>
# <tr>
# <td>THE FOOD HOUSE</td>
# <td>
# </td>
# </tr>
# </tbody>
# </table>
# </li>
# <!-- 2016-03-31 브랜드별 등급표 추가 -->
# </ul>
# </div>
# <a class="close_popup_grade" href="#"><img src="/Images/top/btn_close_popup.gif"/></a>
# </div>
# <div id="navigation">
# <ul class="depth1Ul">
# <li class="depth1">
# <a class="menu1" href="/menu/Menu_New.asp"><img alt="메뉴" src="/Images/top/gnb_1_off.gif"/></a>
# <ul class="depth2Ul depth2Menu1">
# <li><a href="/menu/Menu_New.asp">신제품</a></li>
# <li><a href="/menu/Menu_All.asp">전체메뉴</a></li>
# <li><a href="/menu/SetMenu.asp">세트메뉴</a></li>
# <!-- <li><a href="/menu/MenuList.asp?C2=25">착한메뉴</a></li> -->
# <!-- <li><a href="/menu/MenuList.asp?C2=29">Light Meal</a></li> -->
# <li><a href="/menu/MenuList.asp?C2=4">햄버거</a></li>
# <li><a href="/menu/MenuList.asp?C2=5">치킨</a></li>
# <li><a href="/menu/MenuList.asp?C2=6">디저트</a></li>
# <li><a href="/menu/MenuList.asp?C2=7">드링크</a></li>
# <li><a href="/menu/Menu_Coupon.asp">제품교환권</a></li>
# </ul>
# </li>
# <li class="depth1">
# <!-- <a href="/Shop/HomeService.asp" class="menu1"><img src="/Images/top/gnb_2_off.gif" alt="홈서비스"/></a> -->
# <a class="menu1" href="https://www.lotteeatz.com/" target="_blank"><img alt="롯데잇츠 바로가기" src="/Images/top/gnb_2_off.gif"/></a>
# <div class="depth2Ul depth2Menu2">
# <img alt="홈서비스 / 스마트오더 / 스마트쿠폰" src="/Images/top/menu2_img.png">
# </img></div>
# </li>
# <li class="depth1">
# <a class="menu1" href="/Shop/Shop_List.asp"><img alt="매장찾기" src="/Images/top/gnb_3_off.gif"/></a>
# <div class="depth2Ul depth2Menu3">
# <img alt="가까운 매장정보를 쉽게 찾아보세요!" src="/Images/top/menu3_img.gif">
# </img></div>
# </li>
# <li class="depth1">
# <a class="menu1" href="/Event/Event_List.asp"><img alt="이벤트" src="/Images/top/gnb_4_off.gif"/></a>
# <ul class="depth2Ul depth2Menu4">
# <li><a href="/Event/Event_List.asp">이벤트 소식</a></li>
# <!-- <li><a href="http://lotteriamagazine.com" target='_blank'>맛있는 매거진 L</a></li> -->
# <li><a href="/Board/Board.asp?BoardIdx=1">공지사항</a></li>
# <li><a href="/event/onlinepoll/OnlinePoll_List.asp">온라인폴</a></li>
# <!-- <li><a href="/event/omni.asp">그룹 옴니채널</a></li> -->
# <li><a href="/event/partnerService.asp">제휴 서비스</a></li>
# </ul>
# </li>
# <li class="depth1">
# <a class="menu1" href="/Campaign/ExSchool/Recruit.asp"><img alt="사회공헌캠페인" src="/Images/top/gnb_5_off.gif"/></a>
# <ul class="depth2Ul depth2Menu5">
# <li><a href="/Campaign/ExSchool/Recruit.asp">mom편한 햄버거체험(키즈)</a></li>
# <li><a href="/Campaign/ExProgram/Recruit.asp">mom편한 햄버거체험</a></li>
# <li><a href="/Campaign/GoodWorld/Intro.asp">좋은사람들</a></li>
# <!-- <li><a href="/Campaign/global/global.asp">글로벌원정대</a></li> -->
# <li><a href="/Campaign/Baseball/Recruit.asp">유소년 야구교실</a></li>
# <!-- <li><a href="/Campaign/EnvironmentCamp/Recruit.asp">환경캠프</a></li> -->
# </ul>
# </li>
# <li class="depth1">
# <a class="menu1" href="http://www.lotteriamall.com/" target="_blank"><img alt="롯데리아몰" src="/Images/top/gnb_7_off.gif"/></a>
# </li>
# </ul>
# <a class="closeDepth2" href="#"><img alt="서브메뉴 레이어 닫기" src="/Images/top/btn_close.gif"/></a>
# <!--a href="http://www.lotteriamall.com" target="_blank" title="새창으로 롯데리아 Mall 열기" class="goMallBtn"><img src="/Images/top/gnb_6.gif" alt="롯데리아 Mall"/></a-->
# </div>
# <!-- <div id="gnbSwf">
# 		<script type="text/javascript">swfobject.embedSWF("/Images/swf/gnb.swf?login=0&depth1=0&depth2=1&depth3=&xmlURL=/library/asp/MenuToXML.asp&RETURNURL=%2Fmenu%2FMenu%5FAll%2Easp%3F", "gnbSwf", "100%", "115", "10.0.0","/library/js/expressInstall.swf", "", {menu:"false", wmode:"transparent"}, "");</script>
# 	</div> -->
# </div>
# <div class="depth2background"><span class="depth2visual ir"></span></div>
# </div>
# <!-- //header -->
# <!-- content and aside -->
# <div id="container">
# <!-- <div id="visual">
# 	<script type="text/javascript">swfobject.embedSWF("/Images/swf/subVisual.swf", "visual", "1000", "195", "10.0.0","/library/js/expressInstall.swf", "", {menu:"false", wmode:"transparent"}, "");</script>
# </div> -->
# <div id="linemap">
# <span><a href="/"><img alt="Home" src="/Images/sub/img_home.gif"/></a></span>
# <span class="lineActive">
# <!-- <span class="prevMenu"><a href="#">메뉴</a></span>
# 			<span class="prevMenu"><a href="#">세트메뉴</a></span>
# 			<span class="nowMenu"><a href="#">버거세트</a></span> -->
# </span>
# </div>
# <script type="text/javascript">
# <!--
# //	$(document).ready(function(){
# //		setLinemap({hn : "0", sn : "1", cn : ""});
# //	});
# //	function setLinemap(arg) {
# //		var convertObj = function(obj) {
# //			$.each(obj, function(key, val) {
# //				if(val == "") {
# //					var value = -1;
# //				} else {
# //					var value = Number(val);
# //				}
# //				eval("obj." + key+"=" + value);
# //			});
# //		}
# //		convertObj(arg);
# //		$.ajax({
# //			type: 'get',
# //			url : '/library/xml/menuTree.xml',
# //			datatype: 'xml',
# //			cache:false,
# //			success: function(xml){
# ////				if(window.console) {console.log(arg);}
# //				var $x_tree = $(xml).find("root").find("navi"),
# //					$x_d1 = $x_tree.find("Depth1").eq(arg.hn),
# //					Depth1Name2 = "<span class='prevMenu'><a href='"+$x_d1.attr("param")+"'>"+$x_d1.attr("name")+"</a></span>",
# //					$lineActive = $('.lineActive'),
# //					lineText2 = "";
# //				if(arg.sn != -1) {
# //					var $x_d2 = $x_d1.find("Depth2").eq(arg.sn),
# //						Depth2Name2 = "<span class='prevMenu'><a href='"+$x_d2.attr("param")+"'>"+$x_d2.attr("name")+"</a></span>";
# //					if(arg.cn != -1) {
# //						var $x_d3 = $x_d2.find("Depth3").eq(arg.cn),
# //						Depth3Name2 = "<span class='prevMenu'><a href='"+$x_d3.attr("param")+"'>"+$x_d3.attr("name")+"</a></span>";
# //					} else {
# //						var Depth3Name2 = "xxx";
# //					}
# //				} else {
# //					var Depth2Name2 = "xxx", Depth3Name2 = "xxx";
# //					lineText2 = Depth1Name2;
# //				}
# //				if(Depth3Name2 != "xxx") {
# //					lineText2 =Depth1Name +Depth2Name2 + Depth3Name2;
# //				}
# //				if(Depth2Name2 != "xxx") {
# //					lineText2 =Depth1Name + Depth2Name2;
# //				}
# ////				lineText += Depth1Name;
# //				$lineActive.append(lineText2);
# //				$('.lineActive span').remove('nowMenu');
# //				$('.lineActive span:last-child').addClass('nowMenu');
# //			}
# //		});
# //
# //	}
# //-->
# </script>
# <!-- content -->
# <div id="content">
# <div class="section notice_recruit">
# <!-- content area -->
# <form id="frmNavi" method="get" name="frmNavi">
# <input name="Idx" type="hidden" value=""/>
# <input name="C1" type="hidden" value="2"/>
# <input name="C2" type="hidden" value="0"/>
# <div class="h2">
# <h2><img alt="전체메뉴" src="/Images/menu/h2_menu_all.gif"/></h2>
# <p class="desc"><img alt="롯데리아의 전체메뉴를 만나보세요. ※홈서비스 가격과 상이할 수 있습니다." src="/Images/menu/h2desc_menu_all.gif"/></p>
# </div>
# <div class="roundTop" style="margin-top:0"></div>
# <div class="roundArea">
# <div class="clfix">
# <div class="searchCate1">
# <h4><img alt="가격대 검색" src="/Images/menu/img_txt_1.gif"/></h4>
# <ul>
# <li>
# <input id="priceRdo1" name="priceRdo" type="radio" value="3000"/>
# <label for="priceRdo1">3,000원 이하</label>
# </li>
# <li>
# <input id="priceRdo2" name="priceRdo" type="radio" value="6000"/>
# <label for="priceRdo2">6,000원 이하</label>
# </li>
# <li>
# <input id="priceRdo3" name="priceRdo" type="radio" value="9000"/>
# <label for="priceRdo3">9,000원 이하</label>
# </li>
# <li>
# <input id="priceRdo4" name="priceRdo" type="radio" value="12000"/>
# <label for="priceRdo4">12,000원 이하</label>
# </li>
# <li>
# <input id="priceRdo5" name="priceRdo" type="radio" value="18000"/>
# <label for="priceRdo5">18,000원 이하</label>
# </li>
# <li>
# <input id="priceRdo6" name="priceRdo" type="radio" value="20000"/>
# <label for="priceRdo6">20,000원 이하</label>
# </li>
# </ul>
# </div>
# <div class="searchCate2">
# <h4><img alt="재료별 검색" src="/Images/menu/img_txt_2.gif"/></h4>
# <ul>
# <li>
# <input id="typeRdo1" name="typeRdo" type="checkbox" value="한우"/>
# <label for="typeRdo1">한우</label>
# </li>
# <li>
# <input id="typeRdo2" name="typeRdo" type="checkbox" value="씨푸드"/>
# <label for="typeRdo2">seafood</label>
# </li>
# <li>
# <input id="typeRdo3" name="typeRdo" type="checkbox" value="치킨"/>
# <label for="typeRdo3">치킨</label>
# </li>
# <li>
# <input id="typeRdo4" name="typeRdo" type="checkbox" value="치즈"/>
# <label for="typeRdo4">치즈</label>
# </li>
# </ul>
# <a class="searchBtn" href="#" onclick="setSearch(this.value)"><img alt="검색하기" src="/Images/menu/btn_search_all.gif"/></a>
# </div>
# </div>
# </div>
# <div class="roundBottom"></div>
# <div class="tab_basic_wrap" style="overflow:hidden; padding-top:11px;">
# </div>
# <!-- 리스트 -->
# <div class="h3_group2"> <h3 id="h3CategorySub_8">버거세트</h3></div><div class="memu_group" style="margin-top:10px;"><ul>
# <li style="">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('326', '8');return false;">
# <img alt="핫클라쓰 세트" height="122" src="/Data//Goods/326/ListImage.jpg" width="230"/>
# </a>
# <div style="position:absolute;left:0px;top:0px;width:60px;height:60px;"><img alt="NEW" src="/images/menu/menu_new.png" style="width:57px;height:54px;"/></div>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(326);return false;">핫클라쓰 세트<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>1,231<span>Kcal</span></span>
# <strong>7,200<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# <li style="">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('324', '8');return false;">
# <img alt="마일드클라쓰 세트" height="122" src="/Data//Goods/324/ListImage.jpg" width="230"/>
# </a>
# <div style="position:absolute;left:0px;top:0px;width:60px;height:60px;"><img alt="NEW" src="/images/menu/menu_new.png" style="width:57px;height:54px;"/></div>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(324);return false;">마일드클라쓰 세트<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>1,095<span>Kcal</span></span>
# <strong>6,300<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# <li style="">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('317', '8');return false;">
# <img alt="리아미라클버거 세트" height="122" src="/Data//Goods/317/ListImage.jpg" width="230"/>
# </a>
# <div style="position:absolute;left:0px;top:0px;width:60px;height:60px;"><img alt="NEW" src="/images/menu/menu_new.png" style="width:57px;height:54px;"/></div>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(317);return false;">리아미라클버거 세트<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>968<span>Kcal</span></span>
# <strong>7,400<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# <li style="margin-top: 30px">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('307', '8');return false;">
# <img alt="와규 에디션Ⅱ 세트" height="122" src="/Data//Goods/307/ListImage.jpg" width="230"/>
# </a>
# <div style="position:absolute;left:0px;top:0px;width:60px;height:60px;"><img alt="BEST" src="/images/menu/menu_clean.png" style="width:57px;height:54px;"/></div>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(307);return false;">와규 에디션Ⅱ 세트<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>892<span>Kcal</span></span>
# <strong>7,600<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# <li style="margin-top: 30px">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('300', '8');return false;">
# <img alt="더블X2 세트" height="122" src="/Data//Goods/300/ListImage.jpg" width="230"/>
# </a>
# <div style="position:absolute;left:0px;top:0px;width:60px;height:60px;"><img alt="BEST" src="/images/menu/menu_clean.png" style="width:57px;height:54px;"/></div>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(300);return false;">더블X2 세트<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>1,125<span>Kcal</span></span>
# <strong>7,500<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# <li style="margin-top: 30px">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('297', '8');return false;">
# <img alt="새우버거 세트" height="122" src="/Data//Goods/297/ListImage.jpg" width="230"/>
# </a>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(297);return false;">새우버거 세트<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>886<span>Kcal</span></span>
# <strong>5,900<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# <li style="margin-top: 30px">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('295', '8');return false;">
# <img alt="치킨버거 세트" height="122" src="/Data//Goods/295/ListImage.jpg" width="230"/>
# </a>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(295);return false;">치킨버거 세트<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>779<span>Kcal</span></span>
# <strong>5,100<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# <li style="margin-top: 30px">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('291', '8');return false;">
# <img alt="T-Rex 버거 세트" height="122" src="/Data//Goods/291/ListImage.jpg" width="230"/>
# </a>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(291);return false;">T-Rex 버거 세트<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>870<span>Kcal</span></span>
# <strong>5,900<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# <li style="margin-top: 30px">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('255', '8');return false;">
# <img alt="AZ버거 세트" height="122" src="/Data//Goods/255/ListImage.jpg" width="230"/>
# </a>
# <div style="position:absolute;left:0px;top:0px;width:60px;height:60px;"><img alt="BEST" src="/images/menu/menu_clean.png" style="width:57px;height:54px;"/></div>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(255);return false;">AZ버거 세트<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>941<span>Kcal</span></span>
# <strong>8,300<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# <li style="margin-top: 30px">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('239', '8');return false;">
# <img alt="클래식 치즈버거 세트" height="122" src="/Data//Goods/239/ListImage.jpg" width="230"/>
# </a>
# <div style="position:absolute;left:0px;top:0px;width:60px;height:60px;"><img alt="BEST" src="/images/menu/menu_clean.png" style="width:57px;height:54px;"/></div>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(239);return false;">클래식 치즈버거 세트<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>877<span>Kcal</span></span>
# <strong>6,400<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# <li style="margin-top: 30px">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('237', '8');return false;">
# <img alt="한우연인팩" height="122" src="/Data//Goods/237/ListImage.jpg" width="230"/>
# </a>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(237);return false;">한우연인팩<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>1,714<span>Kcal</span></span>
# <strong>13,900<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# <li style="margin-top: 30px">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('236', '8');return false;">
# <img alt="한우불고기 콤보" height="122" src="/Data//Goods/236/ListImage.jpg" width="230"/>
# </a>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(236);return false;">한우불고기 콤보<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>677<span>Kcal</span></span>
# <strong>8,000<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# <li style="margin-top: 30px">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('235', '8');return false;">
# <img alt="한우불고기 세트" height="122" src="/Data//Goods/235/ListImage.jpg" width="230"/>
# </a>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(235);return false;">한우불고기 세트<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>933<span>Kcal</span></span>
# <strong>8,700<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# <li style="margin-top: 30px">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('234', '8');return false;">
# <img alt="한우명품팩" height="122" src="/Data//Goods/234/ListImage.jpg" width="230"/>
# </a>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(234);return false;">한우명품팩<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>1,830<span>Kcal</span></span>
# <strong>15,600<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# <li style="margin-top: 30px">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('232', '8');return false;">
# <img alt="모짜렐라 인 더 버거 베이컨 세트" height="122" src="/Data//Goods/232/ListImage.jpg" width="230"/>
# </a>
# <div style="position:absolute;left:0px;top:0px;width:60px;height:60px;"><img alt="BEST" src="/images/menu/menu_clean.png" style="width:57px;height:54px;"/></div>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(232);return false;">모짜렐라 인 더 버거 베이컨 세트<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>1,109<span>Kcal</span></span>
# <strong>7,700<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# <li style="margin-top: 30px">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('144', '8');return false;">
# <img alt="원조 빅불 세트" height="122" src="/Data//Goods/144/ListImage.jpg" width="230"/>
# </a>
# <div style="position:absolute;left:0px;top:0px;width:60px;height:60px;"><img alt="BEST" src="/images/menu/menu_clean.png" style="width:57px;height:54px;"/></div>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(144);return false;"><span class="sfont">원조</span> 빅불 세트<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>1,067<span>Kcal</span></span>
# <strong>7,600<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# <li style="margin-top: 30px">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('99', '8');return false;">
# <img alt="핫크리스피버거세트" height="122" src="/Data//Goods/99/ListImage.jpg" width="230"/>
# </a>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(99);return false;">핫크리스피버거세트<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>898<span>Kcal</span></span>
# <strong>6,700<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# <li style="margin-top: 30px">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('89', '8');return false;">
# <img alt="데리버거 세트" height="122" src="/Data//Goods/89/ListImage.jpg" width="230"/>
# </a>
# <div style="position:absolute;left:0px;top:0px;width:60px;height:60px;"><img alt="BEST" src="/images/menu/menu_clean.png" style="width:57px;height:54px;"/></div>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(89);return false;">데리버거 세트<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>750<span>Kcal</span></span>
# <strong>4,900<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# <li style="margin-top: 30px">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('22', '8');return false;">
# <img alt="불고기버거 세트" height="122" src="/Data//Goods/22/ListImage.jpg" width="230"/>
# </a>
# <div style="position:absolute;left:0px;top:0px;width:60px;height:60px;"><img alt="BEST" src="/images/menu/menu_clean.png" style="width:57px;height:54px;"/></div>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(22);return false;">불고기버거 세트<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>836<span>Kcal</span></span>
# <strong>5,900<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# </ul></div><div class="h3_group2"> <h3 id="h3CategorySub_9">치킨세트</h3></div><div class="memu_group" style="margin-top:10px;"><ul>
# <li style="">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('322', '9');return false;">
# <img alt="1인혼닭 세트" height="122" src="/Data//Goods/322/ListImage.jpg" width="230"/>
# </a>
# <div style="position:absolute;left:0px;top:0px;width:60px;height:60px;"><img alt="NEW" src="/images/menu/menu_new.png" style="width:57px;height:54px;"/></div>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(322);return false;">1인혼닭 세트<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>801<span>Kcal</span></span>
# <strong>11,500<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# <li style="">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('79', '9');return false;">
# <img alt="패밀리팩" height="122" src="/Data//Goods/79/ListImage.jpg" width="230"/>
# </a>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(79);return false;">패밀리팩<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>1,712<span>Kcal</span></span>
# <strong>13,600<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# <li style="">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('78', '9');return false;">
# <img alt="치킨풀팩" height="122" src="/Data//Goods/78/ListImage.jpg" width="230"/>
# </a>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(78);return false;">치킨풀팩<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>2,590<span>Kcal</span></span>
# <strong>18,800<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# <li style="margin-top: 30px">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('77', '9');return false;">
# <img alt="치킨하프팩" height="122" src="/Data//Goods/77/ListImage(11).jpg" width="230"/>
# </a>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(77);return false;">치킨하프팩<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>1,232<span>Kcal</span></span>
# <strong>9,300<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# <li style="margin-top: 30px">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('32', '9');return false;">
# <img alt="순살치킨 풀팩" height="122" src="/Data//Goods/32/ListImage.jpg" width="230"/>
# </a>
# <div style="position:absolute;left:0px;top:0px;width:60px;height:60px;"><img alt="BEST" src="/images/menu/menu_best.png" style="width:57px;height:54px;"/></div>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(32);return false;">순살치킨 풀팩<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>1,477<span>Kcal</span></span>
# <strong>15,900<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# <li style="margin-top: 30px">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('31', '9');return false;">
# <img alt="순살치킨 하프팩" height="122" src="/Data//Goods/31/ListImage.jpg" width="230"/>
# </a>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(31);return false;">순살치킨 하프팩<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>739<span>Kcal</span></span>
# <strong>8,900<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# </ul></div><div class="h3_group2"> <h3 id="h3CategorySub_4">햄버거</h3></div><div class="memu_group" style="margin-top:10px;"><ul>
# <li style="">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('325', '4');return false;">
# <img alt="핫클라쓰" height="122" src="/Data//Goods/325/ListImage.jpg" width="230"/>
# </a>
# <div style="position:absolute;left:0px;top:0px;width:60px;height:60px;"><img alt="NEW" src="/images/menu/menu_new.png" style="width:57px;height:54px;"/></div>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(325);return false;">핫클라쓰<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>837<span>Kcal</span></span>
# <strong>5,400<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# <li style="">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('323', '4');return false;">
# <img alt="마일드클라쓰" height="122" src="/Data//Goods/323/ListImage.jpg" width="230"/>
# </a>
# <div style="position:absolute;left:0px;top:0px;width:60px;height:60px;"><img alt="NEW" src="/images/menu/menu_new.png" style="width:57px;height:54px;"/></div>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(323);return false;">마일드클라쓰<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>701<span>Kcal</span></span>
# <strong>4,300<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# <li style="">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('318', '4');return false;">
# <img alt="리아미라클버거" height="122" src="/Data//Goods/318/ListImage.jpg" width="230"/>
# </a>
# <div style="position:absolute;left:0px;top:0px;width:60px;height:60px;"><img alt="NEW" src="/images/menu/menu_new.png" style="width:57px;height:54px;"/></div>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(318);return false;">리아미라클버거<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>574<span>Kcal</span></span>
# <strong>5,600<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# <li style="margin-top: 30px">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('306', '4');return false;">
# <img alt="와규 에디션Ⅱ" height="122" src="/Data//Goods/306/ListImage.jpg" width="230"/>
# </a>
# <div style="position:absolute;left:0px;top:0px;width:60px;height:60px;"><img alt="BEST" src="/images/menu/menu_clean.png" style="width:57px;height:54px;"/></div>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(306);return false;">와규 에디션Ⅱ<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>497<span>Kcal</span></span>
# <strong>5,800<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# <li style="margin-top: 30px">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('299', '4');return false;">
# <img alt="더블X2" height="122" src="/Data//Goods/299/ListImage.jpg" width="230"/>
# </a>
# <div style="position:absolute;left:0px;top:0px;width:60px;height:60px;"><img alt="BEST" src="/images/menu/menu_clean.png" style="width:57px;height:54px;"/></div>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(299);return false;">더블X2<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>730<span>Kcal</span></span>
# <strong>5,500<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# <li style="margin-top: 30px">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('296', '4');return false;">
# <img alt="새우버거" height="122" src="/Data//Goods/296/ListImage.jpg" width="230"/>
# </a>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(296);return false;">새우버거<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>492<span>Kcal</span></span>
# <strong>3,900<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# <li style="margin-top: 30px">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('294', '4');return false;">
# <img alt="치킨버거" height="122" src="/Data//Goods/294/ListImage.jpg" width="230"/>
# </a>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(294);return false;">치킨버거<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>355<span>Kcal</span></span>
# <strong>2,900<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# <li style="margin-top: 30px">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('290', '4');return false;">
# <img alt="T-Rex" height="122" src="/Data//Goods/290/ListImage.jpg" width="230"/>
# </a>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(290);return false;">T-Rex<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>475<span>Kcal</span></span>
# <strong>3,700<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# <li style="margin-top: 30px">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('238', '4');return false;">
# <img alt="클래식 치즈버거" height="122" src="/Data//Goods/238/ListImage.jpg" width="230"/>
# </a>
# <div style="position:absolute;left:0px;top:0px;width:60px;height:60px;"><img alt="BEST" src="/images/menu/menu_clean.png" style="width:57px;height:54px;"/></div>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(238);return false;">클래식 치즈버거<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>483<span>Kcal</span></span>
# <strong>4,400<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# <li style="margin-top: 30px">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('233', '4');return false;">
# <img alt="한우불고기" height="122" src="/Data//Goods/233/ListImage.jpg" width="230"/>
# </a>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(233);return false;">한우불고기<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>539<span>Kcal</span></span>
# <strong>7,000<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# <li style="margin-top: 30px">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('231', '4');return false;">
# <img alt="모짜렐라 인 더 버거 - 베이컨" height="122" src="/Data//Goods/231/ListImage.jpg" width="230"/>
# </a>
# <div style="position:absolute;left:0px;top:0px;width:60px;height:60px;"><img alt="BEST" src="/images/menu/menu_clean.png" style="width:57px;height:54px;"/></div>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(231);return false;">모짜렐라 인 더 버거 - 베이컨<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>715<span>Kcal</span></span>
# <strong>6,000<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# <li style="margin-top: 30px">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('219', '4');return false;">
# <img alt="AZ버거" height="122" src="/Data//Goods/219/ListImage.jpg" width="230"/>
# </a>
# <div style="position:absolute;left:0px;top:0px;width:60px;height:60px;"><img alt="BEST" src="/images/menu/menu_clean.png" style="width:57px;height:54px;"/></div>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(219);return false;">AZ버거<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>547<span>Kcal</span></span>
# <strong>6,600<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# <li style="margin-top: 30px">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('143', '4');return false;">
# <img alt="원조 빅불" height="122" src="/Data//Goods/143/ListImage.jpg" width="230"/>
# </a>
# <div style="position:absolute;left:0px;top:0px;width:60px;height:60px;"><img alt="BEST" src="/images/menu/menu_clean.png" style="width:57px;height:54px;"/></div>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(143);return false;"><span class="sfont">원조</span> 빅불<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>672<span>Kcal</span></span>
# <strong>5,800<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# <li style="margin-top: 30px">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('100', '4');return false;">
# <img alt="핫크리스피버거" height="122" src="/Data//Goods/100/ListImage.jpg" width="230"/>
# </a>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(100);return false;">핫크리스피버거<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>503<span>Kcal</span></span>
# <strong>4,900<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# <li style="margin-top: 30px">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('68', '4');return false;">
# <img alt="불고기버거" height="122" src="/Data//Goods/68/ListImage.jpg" width="230"/>
# </a>
# <div style="position:absolute;left:0px;top:0px;width:60px;height:60px;"><img alt="BEST" src="/images/menu/menu_clean.png" style="width:57px;height:54px;"/></div>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(68);return false;">불고기버거<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>442<span>Kcal</span></span>
# <strong>3,900<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# <li style="margin-top: 30px">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('26', '4');return false;">
# <img alt="데리버거" height="122" src="/Data//Goods/26/ListImage.jpg" width="230"/>
# </a>
# <div style="position:absolute;left:0px;top:0px;width:60px;height:60px;"><img alt="BEST" src="/images/menu/menu_clean.png" style="width:57px;height:54px;"/></div>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(26);return false;">데리버거<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>356<span>Kcal</span></span>
# <strong>2,500<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# </ul></div><div class="h3_group2"> <h3 id="h3CategorySub_5">치킨</h3></div><div class="memu_group" style="margin-top:10px;"><ul>
# <li style="">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('319', '5');return false;">
# <img alt="1인혼닭" height="122" src="/Data//Goods/319/ListImage.jpg" width="230"/>
# </a>
# <div style="position:absolute;left:0px;top:0px;width:60px;height:60px;"><img alt="NEW" src="/images/menu/menu_new.png" style="width:57px;height:54px;"/></div>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(319);return false;">1인혼닭<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>581<span>Kcal</span></span>
# <strong>10,000<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# <li style="">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('76', '5');return false;">
# <img alt="치킨휠레 (4조각)" height="122" src="/Data//Goods/76/ListImage.jpg" width="230"/>
# </a>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(76);return false;">치킨휠레 (4조각)<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>366<span>Kcal</span></span>
# <strong>4,500<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# <li style="">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('20', '5');return false;">
# <img alt="화이어윙 (2조각)" height="122" src="/Data//Goods/20/ListImage.jpg" width="230"/>
# </a>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(20);return false;">화이어윙 (2조각)<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>176<span>Kcal</span></span>
# <strong>2,500<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# <li style="margin-top: 30px">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('19', '5');return false;">
# <img alt="화이어윙 (4조각)" height="122" src="/Data//Goods/19/ListImage.jpg" width="230"/>
# </a>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(19);return false;">화이어윙 (4조각)<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>353<span>Kcal</span></span>
# <strong>4,500<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# <li style="margin-top: 30px">
# <div class="thumb">
# <div class="img">
# <div style="position:relative;width:250px;height:100px;">
# <a href="#" onclick="goView('8', '5');return false;">
# <img alt="치킨1조각" height="122" src="/Data//Goods/8/ListImage.jpg" width="230"/>
# </a>
# </div>
# </div>
# </div>
# <div class="bx_flex menuRoundWrap">
# <span class="roundTop"></span>
# <div class="cont menu roundMiddle">
# <a href="#" onclick="goView(8);return false;">치킨1조각<img alt="" src="/Images/common/bul_link_menu.gif"/></a>
# <span>272<span>Kcal</span></span>
# <strong>2,300<span class="ir hiddenSpan">원</span></strong>
# </div>
# <span class="roundBottom"></span>
# </div>
# </li>
# <li style="margin-top: 30px">
# <div class="thumb">
# <div class="img">
# ...
# </ul>
# </li>
# <li>
# <a href="http://company.lottechilsung.co.kr" target="_blank" title="새창으로 열기">롯데칠성음료</a>
# <ul>
# <li><a href="http://mall.lottechilsung.co.kr/index.html" target="_blank" title="새창으로 열기">- 롯데칠성몰</a></li>
# </ul>
# </li>
# <li>
# <a href="http://www.lottefoods.co.kr" target="_blank" title="새창으로 열기">롯데푸드</a>
# <ul>
# <li><a href="http://www.pasteur.co.kr" target="_blank" title="새창으로 열기">- 파스퇴르</a></li>
# <li><a href="http://www.pasteurmall.com" target="_blank" title="새창으로 열기">- 파스퇴르몰</a></li>
# <li><a href="http://www.pasteuri.com" target="_blank" title="새창으로 열기">- 파스퇴르아이</a></li>
# <li><a href="http://www.chefood.co.kr" target="_blank" title="새창으로 열기">- 쉐푸드</a></li>
# <li><a href="http://www.en-nature.co.kr" target="_blank" title="새창으로 열기">- 엔네이처</a></li>
# <li><a href="http://www.lottevienna.co.kr" target="_blank" title="새창으로 열기">- 롯데비엔나</a></li>
# <li><a href="http://www.kisstick.co.kr" target="_blank" title="새창으로 열기">- 키스틱</a></li>
# <li><a href="http://www.uiseongham.co.kr" target="_blank" title="새창으로 열기">- 의성마늘햄</a></li>
# <!-- <li><a href="http://www.benecol.co.kr" target="_blank" title="새창으로 열기">- 베네콜</a></li> -->
# </ul>
# </li>
# <li>
# <a href="http://www.lotteliquor.com" target="_blank" title="새창으로 열기">롯데주류BG </a>
# <ul>
# <li><a href="http://www.wine.co.kr" target="_blank" title="새창으로 열기">- WINE</a></li>
# <!-- <li><a href="http://www.kloudbeer.com" target="_blank" title="새창으로 열기">- 클라우드</a></li> -->
# </ul>
# </li>
# <li><a href="http://www.lotteasahi.co.kr" target="_blank" title="새창으로 열기">롯데아사히주류</a></li>
# <li><a href="http://www.lotteliquor.com/" target="_blank" title="새창으로 열기">롯데칠성주류</a></li>
# <li>
# <a href="http://store.lotteshopping.com" target="_blank" title="새창으로 열기">롯데백화점</a>
# <ul>
# <li><a href="http://www.ellotte.com" target="_blank" title="새창으로 열기">- 엘롯데</a></li>
# <li><a href="http://store.lotteshopping.com/handler/Main-Start?subBrchCd=021&amp;gubun=2" target="_blank" title="새창으로 열기">- 영플라자</a></li>
# <li><a href="http://store.lotteshopping.com/handler/Main-Start?subBrchCd=054&amp;gubun=1" target="_blank" title="새창으로 열기">- 프리미엄아울렛</a></li>
# <li><a href="http://store.lotteshopping.com/handler/Main-Start?subBrchCd=057" target="_blank" title="새창으로 열기">- 롯데아울렛</a></li>
# <li><a href="http://buying.lotteshopping.com" target="_blank" title="새창으로 열기">- 상품본부</a></li>
# <!-- <li><a href="http://lotteedi.dpt.co.kr" target="_blank" title="새창으로 열기">- EDI시스템</a></li> -->
# </ul>
# </li>
# <li><a href="https://www.lotteshopping.com/main/main" target="_blank" title="새창으로 열기">에비뉴엘</a></li>
# <li>
# <a href="http://www.lottemart.com" target="_blank" title="새창으로 열기">롯데마트</a>
# <ul>
# <li><a href="http://company.lottemart.com" target="_blank" title="새창으로 열기">- 롯데마트 홍보</a></li>
# </ul>
# </li>
# <li>
# <a href="http://www.e-himart.co.kr" target="_blank" title="새창으로 열기">롯데하이마트</a>
# <ul>
# <li><a href="http://www.vic-market.com" target="_blank" title="새창으로 열기">- 롯데하이마트 홍보</a></li>
# </ul>
# </li>
# <li><a href="http://toysrus.lottemart.com" target="_blank" title="새창으로 열기">토이저러스</a></li>
# <li><a href="http://www.lottesuper.co.kr" target="_blank" title="새창으로 열기">롯데슈퍼</a></li>
# <li><a href="http://www.vic-market.com" target="_blank" title="새창으로 열기">롯데빅마켓</a></li>
# <li><a href="http://www.lottecinema.co.kr" target="_blank" title="새창으로 열기">롯데시네마</a></li>
# <li><a href="http://www.lotteimall.com " target="_blank" title="새창으로 열기">롯데홈쇼핑</a></li>
# <li><a href="http://www.7-eleven.co.kr" target="_blank" title="새창으로 열기">코리아세븐</a></li>
# <li><a href="https://store-kr.uniqlo.com/" target="_blank" title="새창으로 열기">유니클로</a></li>
# <li><a href="http://www.muji.com" target="_blank" title="새창으로 열기">무인양품</a></li>
# <li><a href="http://www.lotteintl.co.kr" target="_blank" title="새창으로 열기">롯데상사</a></li>
# <li><a href="http://www.lotte.com" target="_blank" title="새창으로 열기">롯데닷컴</a></li>
# <li><a href="http://www.lottelmsc.com" target="_blank" title="새창으로 열기">롯데유통사업본부</a></li>
# <li><a href="http://www.charlottetheater.co.kr" target="_blank" title="새창으로 열기">샤롯데씨어터</a></li>
# <li><a href="http://www.lohbs.co.kr" target="_blank" title="새창으로 열기">H&amp;B(롭스)</a></li>
# <li><a href="http://www.lottefitin.com" target="_blank" title="새창으로 열기">롯데피트인</a></li>
# <li><a href="http://www.lottehotel.com" target="_blank" title="새창으로 열기">롯데호텔</a></li>
# <li><a href="http://kr.lottedfs.com" target="_blank" title="새창으로 열기">롯데면세점</a></li>
# <li><a href="http://www.lottedfs.com" target="_blank" title="새창으로 열기">롯데인터넷면세점</a></li>
# <li><a href="http://www.busanlottedfs.com" target="_blank" title="새창으로 열기">부산롯데인터넷면세점</a></li>
# <li>
# <a href="http://www.lotteworld.com" target="_blank" title="새창으로 열기">롯데월드</a>
# <ul>
# <li><a href="http://www.lotteworld.com/waterpark/index.asp" target="_blank" title="새창으로 열기">- 워터파크</a></li>
# <li><a href="http://www.lotteworld.com/aquarium/index.asp" target="_blank" title="새창으로 열기">- 아쿠아리움</a></li>
# </ul>
# </li>
# <li><a href="http://www.lottecorp.com" target="_blank" title="새창으로 열기">롯데물산</a></li>
# <li><a href="http://www.lwt.co.kr" target="_blank" title="새창으로 열기">롯데월드타워&amp;몰</a></li>
# <li><a href="http://gimpoairport.lottemall.co.kr" target="_blank" title="새창으로 열기">롯데몰 김포공항점</a></li>
# <li><a href="http://www.lottejtb.com" target="_blank" title="새창으로 열기">롯데제이티비</a></li>
# <li>
# <a href="http://www.lotteins.co.kr" target="_blank" title="새창으로 열기">롯데손해보험</a>
# <ul>
# <li><a href="http://www.3655.co.kr" target="_blank" title="새창으로 열기">- 롯데하우머치</a></li>
# </ul>
# </li>
# <li><a href="http://www.lottecard.co.kr" target="_blank" title="새창으로 열기">롯데카드</a></li>
# <li><a href="http://www.lottecap.com" target="_blank" title="새창으로 열기">롯데캐피탈</a></li>
# <li>
# <a href="http://www.lottecon.co.kr" target="_blank" title="새창으로 열기">롯데건설</a>
# <ul>
# <li><a href="http://www.lottecastle.co.kr" target="_blank" title="새창으로 열기">- 롯데캐슬</a></li>
# </ul>
# </li>
# <li>
# <a href="http://www.fujifilm.co.kr" target="_blank" title="새창으로 열기">한국후지필름</a>
# <ul>
# <li><a href="http://shop.fujifilm.co.kr" target="_blank" title="새창으로 열기">- 후지필름쇼핑몰</a></li>
# <li><a href="http://www.astalift.co.kr" target="_blank" title="새창으로 열기">- 아스타리프트</a></li>
# </ul>
# </li>
# <li><a href="http://www.lotteal.co.kr" target="_blank" title="새창으로 열기">롯데알미늄</a>
# <ul>
# <li><a href="http://www.lotteelife.co.kr" target="_blank" title="새창으로 열기">- 롯데이라이프</a></li>
# </ul>
# </li>
# <li><a href="http://www.lottechem.com" target="_blank" title="새창으로 열기">롯데케미칼</a></li>
# <li><a href="http://www.lottemcc.com" target="_blank" title="새창으로 열기">롯데엠시시</a></li>
# <li><a href="http://www.canon-bs.co.kr" target="_blank" title="새창으로 열기">캐논코리아 비즈니스솔루션</a></li>
# <li><a href="http://www.lottelem.co.kr" target="_blank" title="새창으로 열기">롯데기공</a></li>
# <li><a href="http://www.lotteacademy.co.kr" target="_blank" title="새창으로 열기">롯데인재개발원</a></li>
# <li><a href="http://ez.lotteacademy.co.kr" target="_blank" title="새창으로 열기">사이버 인재개발원</a></li>
# <li><a href="http://www.ldcc.co.kr" target="_blank" title="새창으로 열기">롯데정보통신</a></li>
# <li><a href="http://www.giantsclub.com" target="_blank" title="새창으로 열기">롯데자이언츠</a></li>
# <li><a href="http://www.skyhill.co.kr" target="_blank" title="새창으로 열기">롯데스카이힐C.C</a></li>
# <li><a href="https://www.lotteresortsokcho.com" target="_blank" title="새창으로 열기">롯데리조트 속초</a></li>
# <li><a href="http://www.lottebuyeoresort.com" target="_blank" title="새창으로 열기">롯데리조트 부여</a></li>
# <li><a href="http://www.lottejejuresort.com/" target="_blank" title="새창으로 열기">롯데리조트 제주</a></li>
# <li><a href="http://www.daehong.com" target="_blank" title="새창으로 열기">대홍기획</a></li>
# <li><a href="http://www.cashbee.co.kr" target="_blank" title="새창으로 열기">캐시비</a></li>
# <li><a href="http://www.mybi.co.kr" target="_blank" title="새창으로 열기">마이비</a></li>
# <li><a href="http://www.lotternd.com" target="_blank" title="새창으로 열기">롯데중앙연구소</a></li>
# <li><a href="http://www.llc.co.kr" target="_blank" title="새창으로 열기">롯데로지스틱스</a></li>
# <li><a href="http://www.lottefoundation.or.kr" target="_blank" title="새창으로 열기">롯데재단</a></li>
# <li><a href="http://www.lotterentacar.net" target="_blank" title="새창으로 열기">롯데렌터카</a></li>
# <li><a href="http://www.lotteconcerthall.com/" target="_blank" title="새창으로 열기">롯데콘서트홀</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="clfix">
# <address><img alt="COPYRIGHT © 2013 LOTTERIA GRS CO.,LTD ALL RIGHT RESERVED" src="/Images/common/footer-copyright.gif"/></address>
# <span class="ie8"><img alt="현 웹사이트는 Internet Explorer 8.0 이상에 최적화 되어 있습니다." src="/Images/common/ie8.png"/></span>
# </div>
# </div>
# </div>
# <!--http 리아 구글애널리틱스 스크립트 -->
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-88656313-1', 'auto');
#   ga('send', 'pageview');
# </script>
# <script type="text/javascript">
# <!--
# function changeRnb(){
# 	var depth2Num = '1';
# 	var depth3Num = '';
# 	var maxNum = $('.rnbNavigation').find('.rnbDepth1').length;
# 	$('.rnbNavigation').find('.rnbDepth1').removeClass('on');
# 	$('.rnbNavigation').find('.rnbDepth1').eq(depth2Num).addClass('on');
# 	if(depth2Num == 0){
# 		$('.topImg').removeClass('off');
# 		$('.topImg').addClass('on');
# 	}else if(depth2Num == (maxNum-1)){
# 		$('.bottomImg').removeClass('off');
# 		$('.bottomImg').addClass('on');
# 	}
# 	$('.rnbNavigation').find('.rnbDepth1').eq(depth2Num).find('.hiddenMenu').show().find('li').eq(depth3Num).addClass('on');
#
# }
# // 1depth 클릭시 펼쳐짐
# function accordionFn(){
# 	$('.rnbDepth1>a').bind('click',function(){
# //		alert(1234);
# //		if($(this).next().attr('class')=='hiddenMenu'){ // 하위메뉴 존재할때
# //			$('.hiddenMenu').hide();
# //			$(this).next().stop();
# //			$(this).next().show();
# //			return false;
# //		}
# 	});
# }
#
# // famlysite toggle
# function toggleFamily(){
# 	$('#footer .inner ul.fnbUl li a').bind('focus',function(){
# 		$('.familyShowLayer').hide();
# 	});
# //	$('.familyToggle').bind('blur',function(){
# //		if($('.familyShowLayer').css('display') == 'none'){
# //			$('.familyShowLayer').show();
# //		}else{
# //			$('.familyShowLayer').show();
# //		}
# //		return false;
# //	});
# 	$('.familyShowLayer ul.familyDepth1Ul>li:last-child a').bind('blur',function(){
# 		$('.familyShowLayer').hide();
# //		$('.familyToggle').focus();
# 	});
# 	$('.familyToggle').click(function(){return false});
# 	$('.familyToggle').bind('mouseover focus',function(){
# 		$('.familyShowLayer').show();
# 	});
# 	$(document).bind('mouseout', function(e) {
# 		var $clicked = $(e.target);
# 		if (!$clicked.parents().hasClass("familyWrap")){
# //			console.log($clicked);
# 			$(".familyShowLayer").hide();
# 		}
# //		if (!$clicked.parents().hasClass("footerArea")){
# ////			console.log($clicked);
# //			$(".familyShowLayer").hide();
# //		}
# //		if (!$clicked.parents().attr('id')==('footer')){
# ////			console.log($clicked);
# //			$(".familyShowLayer").hide();
# //		}
# 	});
# }
# $(document).ready(function(){
# 	changeRnb();
# 	accordionFn();
# 	setTimeout('changeRnb()',500);
# 	setTimeout('accordionFn()',1000);
# 	toggleFamily();
# });
# //-->
# </script>
# <script type="text/javascript">
# <!--
# 	$(document).ready(function(){
# 		showDepth2Fn();
# 		changeDepth2Img();
# 		$('.closeDepth2').click(function(){
# 			resetDepth2();
# 			$('.goMallBtn').focus();
# 			return false;
# 		});
# 		$('#gnb h1 a,.goMallBtn').focus(function(){
# 			resetDepth2();
# 		});
# 		setTitle({hn : '0', sn : '1', cn : ''});
# 	});
# 	// 네비게이션 관련 스크립트
#
# 	// 1뎁스 메뉴 오버 시 이미지 변경 함수
# 	function showDepth2Fn(){
# 		$('.depth1>a').bind('focus mouseover',function(){
# 			$('.depth2Ul a').each(function(){
# 				$(this).removeClass('on');
# 			});
# 			$(this).next().find('li').eq(0).find('a').addClass('on');
# 			$('#header').css('background','url(/Images/top/bg_header_on.gif) 0 0 repeat-x'); // 헤더 배경 변경
# 			$('.depth1 .menu1 img').each(function(){
# 				var menu1Onsrc = $(this).attr('src');
# 				$(this).attr('src',menu1Onsrc.replace('_on.gif','_off.gif'));
# 			});
# 			var offSrc = $(this).find('img').attr('src');
# 			$(this).find('img').attr('src',offSrc.replace('_off.gif','_on.gif'));
# 			showDepth2All();
# 		});
# 	}
#
# 	// 2뎁스 메뉴 보여지기 함수
# 	function showDepth2All(){
# 		menusetcount = 0;
# 		$('.depth2background,.depth2Ul,.closeDepth2').show();
# 	}
# 	// 2뎁스 마우스 오버시 배경 변경 함수
# 	function changeDepth2Img(){
# 		$('.depth2Ul a').bind('focus mouseover',function(){
# 			var depth2Index = $(this).parentsUntil('.depth1').parent().index();
# 			$('.depth1 .menu1 img').each(function(){
# 				var menu1Onsrc = $(this).attr('src');
# 				$(this).attr('src',menu1Onsrc.replace('_on.gif','_off.gif'));
# 			});
# 			$('.depth1').eq(depth2Index).find('.menu1 img').attr('src',$('.depth1').eq(depth2Index).find('.menu1 img').attr('src').replace('_off.gif','_on.gif'));
# 			$('.depth2Ul a').each(function(){
# 				$(this).removeClass('on');
# 			});
# 			$(this).addClass('on');
# 		});
# 	}
# 	// 2뎁스 리셋 함수
# 	menusetcount = 0;
# 	function resetDepth2(){
# 		menusetcount++;
# 		$('.depth1 .menu1 img').each(function(){
# 			var menu1Onsrc = $(this).attr('src');
# 			$(this).attr('src',menu1Onsrc.replace('_on.gif','_off.gif'));
# 		});
# 		$('.depth2background,.depth2Ul,.closeDepth2').hide();
# 		$('#header').css('background','url(/Images/top/bg_header.gif) 0 0 repeat-x');
# 		setPage();
# 	}
# 	// 2뎁스 마우스 아웃시
# 	$(document).bind('mouseover', function(e) {
# 		var $clicked = $(e.target);
# 		if (! $clicked.parents().hasClass("gnbNavi")){
# 			if (menusetcount ==0){
# 				resetDepth2();
# 			}
# 		}
# 	});
# 	// 메뉴 활성화
# 	function setPage() { //navigation hn:1depth, sn:2depth, cn:3depth 를 받음
# 		var hn= parseInt(0);
# 		var ha= parseInt();
# 		if (hn>6){
# 			return false;
# 		}else if (ha>=0){
# 			return false;
# 		}else{
# 			$('.depth1Ul').find('.depth1').eq((hn)).find('.menu1 img').attr('src',$('.depth1Ul').find('.depth1').eq((hn)).find('.menu1 img').attr('src').replace('_off.gif','_on.gif'));
# 		}
# 	}
# 	function setTitle(arg) {
# 		var convertObj = function(obj) {
# 			$.each(obj, function(key, val) {
# 				if(val == "") {
# 					var value = -1;
# 				} else {
# 					var value = Number(val);
# 				}
# 				eval("obj." + key+"=" + value);
# 			});
# 		}
# 		convertObj(arg);
#
# 		$.ajax({
# 			type: 'get',
# 			url : '/library/xml/menuTree.xml',
# 			datatype: 'xml',
# 			cache:false,
# 			success: function(xml){
#
# //				if(window.console) {console.log(arg);}
# 				var $x_tree = $(xml).find("root").find("navi"),
# 					$x_d1 = $x_tree.find("Depth1").eq(arg.hn),
# 					Depth1Name = $x_d1.attr("name"),
# 					titleText = "";
# 					Depth1Name2 = "<span class='prevMenu'><a href='"+$x_d1.attr("param")+"'>"+$x_d1.attr("name")+"</a></span>",
# 					$lineActive = $('.lineActive'),
# 					lineText2 = "";
# 				if(arg.sn != -1) {
# 					var $x_d2 = $x_d1.find("Depth2").eq(arg.sn),
# 						Depth2Name = $x_d2.attr("name");
# 						Depth2Name2 = "<span class='prevMenu'><a href='"+$x_d2.attr("param")+"'>"+$x_d2.attr("name")+"</a></span>";
# 					if(arg.cn != -1) {
# 						var $x_d3 = $x_d2.find("Depth3").eq(arg.cn),
# 						Depth3Name = $x_d3.attr("name");
# 						Depth3Name2 = "<span class='prevMenu'><a href='"+$x_d3.attr("param")+"'>"+$x_d3.attr("name")+"</a></span>";
# 					} else {
# 						var Depth3Name = "xxx";
# 						var Depth3Name2 = "xxx";
# 					}
# 				} else {
# 					var Depth2Name = "xxx", Depth3Name = "xxx";
# 					var Depth2Name2 = "xxx", Depth3Name2 = "xxx";
# 					lineText2 = Depth1Name2;
# 				}
#
# 				/*
# 				if($('title').text()!='롯데리아'){
# 					titleText = $('title').text() + ' | ' + titleText;
# 				}else{
# 					if($.type($('input[name=h_title]').val())!=='undefined'){
# 						titleText = $('input[name=h_title]').val() + ' | ' + titleText;
# 					}
# 				}
# 				*/
# 				titleText = Depth1Name;
# 				if(Depth2Name != "xxx") {
# 					titleText = Depth2Name;
# 				}
# 				if(Depth3Name != "xxx") {
# 					titleText = Depth3Name;
# 				}
# 				if($('input[name=h_title]').length) {
# 					titleText += "(" + $('input[name=h_title]').val() + ")";
# 				}
#
# 				if(Depth3Name2 != "xxx") {
# 					lineText2 =Depth1Name2 +Depth2Name2 + Depth3Name2;
# 				}
# 				if(Depth2Name2 != "xxx") {
# 					lineText2 =Depth1Name2 + Depth2Name2;
# 				}
# 				$lineActive.append(lineText2);
# 				$('.lineActive span').remove('nowMenu');
# 				$('.lineActive span:last-child').addClass('nowMenu');
# 				document.title = titleText + " | 롯데리아";
# 				$('.rightGnb h3 img').attr('alt',Depth1Name);
# 			}
# 		});
# 	}
# //-->
# </script>
# </body>
# </html>

# %% [markdown]
# ### 원하는 정보 크롤링하기 - menu_list, kcal_list, price_list 라는 3가지 리스트에 각각 모든 메뉴, 칼로리, 가격 정보 모두 넣기(단 kcal, 원 단위는 생략)

# %%
menu_list = []
kcal_list = []
price_list = []

menu_list_all = soup.select('div.cont.menu.roundMiddle>a')
kcal_list_all = soup.select('div.cont.menu.roundMiddle>span')
price_list_all = soup.select('div.cont.menu.roundMiddle>strong')

for tag in menu_list_all:
    menu_list.append(tag.text)
for tag in kcal_list_all:
    kcal_list.append(tag.text[:-4])
for tag in price_list_all:
    price_list.append(tag.text[:-1])
    
price_list
#select_one, select, find, find_all 4가지 연산자 중 선택하여 사용하면 됩니다.
# Out:
# ['7,200',
#  '6,300',
#  '7,400',
#  '7,600',
#  '7,500',
#  '5,900',
#  '5,100',
#  '5,900',
#  '8,300',
#  '6,400',
#  '13,900',
#  '8,000',
#  '8,700',
#  '15,600',
#  '7,700',
#  '7,600',
#  '6,700',
#  '4,900',
#  '5,900',
#  '11,500',
#  '13,600',
#  '18,800',
#  '9,300',
#  '15,900',
#  '8,900',
#  '5,400',
#  '4,300',
#  '5,600',
#  '5,800',
#  '5,500',
#  '3,900',
#  '2,900',
#  '3,700',
#  '4,400',
#  '7,000',
#  '6,000',
#  '6,600',
#  '5,800',
#  '4,900',
#  '3,900',
#  '2,500',
#  '10,000',
#  '4,500',
#  '2,500',
#  '4,500',
#  '2,300',
#  '2,500',
#  '3,800',
#  '3,000',
#  '4,300',
#  '3,400',
#  '1,200',
#  '1,800',
#  '1,700',
#  '1,500',
#  '2,500',
#  '2,500',
#  '2,500',
#  '2,000',
#  '2,200',
#  '2,000',
#  '1,500',
#  '2,300',
#  '2,300',
#  '2,400',
#  '700',
#  '2,200',
#  '2,500',
#  '2,000',
#  '2,500',
#  '1,500',
#  '1,700',
#  '1,700',
#  '2,100',
#  '2,100',
#  '2,100',
#  '2,000',
#  '2,000',
#  '2,400',
#  '2,400',
#  '2,500']

# %% [markdown]
# ### 가져온 정보(3개의 리스트)를 딕셔너리 형태로 만들기(칼럼명, 순서는 'menu', 'kcal', 'price') + 데이터프레임으로 만들어 5줄만 나타내기 (칼럼 순서 지켜야 함!)

# %%
dic = {'menu': menu_list, 'kcal': kcal_list, 'price': price_list}
data = pd.DataFrame(dic)
data
# Out:
#           menu   kcal  price
# 0      핫클라쓰 세트  1,231  7,200
# 1    마일드클라쓰 세트  1,095  6,300
# 2   리아미라클버거 세트    968  7,400
# 3   와규 에디션Ⅱ 세트    892  7,600
# 4      더블X2 세트  1,125  7,500
# ..         ...    ...    ...
# 76       아메리카노     34  2,000
# 77   아이스 아메리카노     32  2,000
# 78        카페라떼    210  2,400
# 79    아이스 카페라떼     98  2,400
# 80       레몬에이드    151  2,500
#
# [81 rows x 3 columns]

# %% [markdown]
# ### test 폴더에 csv파일로 저장 (파일이름은 '롯데리아메뉴', 엑셀 파일을 열었을 때 한글이 깨지지 않고, 인덱스 없이 저장하기)

# %%
data.to_csv("롯데리아메뉴.csv", index=False, encoding='euc-kr')

# %% [markdown]
# ### df 변수에 저장했던 csv파일 불러오기, 옵션에 thousands=',' 추가하여 천 단위 표현(,)생략 + 5줄 나타내기

# %%
df = pd.read_csv('롯데리아메뉴.csv', encoding='euc-kr', thousands=',')
df.head()
# Out:
#          menu  kcal  price
# 0     핫클라쓰 세트  1231   7200
# 1   마일드클라쓰 세트  1095   6300
# 2  리아미라클버거 세트   968   7400
# 3  와규 에디션Ⅱ 세트   892   7600
# 4     더블X2 세트  1125   7500

# %% [markdown]
# ### df의 총 데이터 건수, 데이터 타입, Null 건수를 한 번에 알아보기

# %%
df.info
# Out:
# <bound method DataFrame.info of           menu  kcal  price
# 0      핫클라쓰 세트  1231   7200
# 1    마일드클라쓰 세트  1095   6300
# 2   리아미라클버거 세트   968   7400
# 3   와규 에디션Ⅱ 세트   892   7600
# 4      더블X2 세트  1125   7500
# ..         ...   ...    ...
# 76       아메리카노    34   2000
# 77   아이스 아메리카노    32   2000
# 78        카페라떼   210   2400
# 79    아이스 카페라떼    98   2400
# 80       레몬에이드   151   2500
#
# [81 rows x 3 columns]>

# %% [markdown]
# ### df의 'menu' 칼럼명을 '메뉴'로 수정하기

# %%
df.rename(columns={df.columns[0]: '메뉴'}, inplace=True)
df.head()
# Out:
#            메뉴  kcal  price
# 0     핫클라쓰 세트  1231   7200
# 1   마일드클라쓰 세트  1095   6300
# 2  리아미라클버거 세트   968   7400
# 3  와규 에디션Ⅱ 세트   892   7600
# 4     더블X2 세트  1125   7500

# %% [markdown]
# ### df의 인덱스를 확인하기

# %%
df.index
# Out:
# RangeIndex(start=0, stop=81, step=1)

# %% [markdown]
# ### (loc, iloc 명령 중 선택하여 사용) df의 인덱스를 확인하여 맨 마지막 그 다음 행(81번째 행)에 '메뉴'는 '오미자에이드', 'kcal'는 140, 'price'는 3000 정보를 가진 행 추가하기 + 맨 마지막 행 확인하기

# %%
df.loc[81] = {'메뉴' : '오미자에이드', 'kcal' : 140, 'price' : 3000}
df.iloc[-1]
# Out:
# 메뉴       오미자에이드
# kcal        140
# price      3000
# Name: 81, dtype: object

# %% [markdown]
# ### df를 복사하여 df2라는 새로운 데이터프레임 만들기

# %%
df2= df.copy()

# %% [markdown]
# ### df2 에 '만족도'라는 새로운 칼럼을 만들어  '만족도' 값이 모두 NaN값을 가지도록 하기 + 5줄 나타내기

# %%
df2['만족도']=np.nan
df2.head()
# Out:
#            메뉴  kcal  price  만족도
# 0     핫클라쓰 세트  1231   7200  NaN
# 1   마일드클라쓰 세트  1095   6300  NaN
# 2  리아미라클버거 세트   968   7400  NaN
# 3  와규 에디션Ⅱ 세트   892   7600  NaN
# 4     더블X2 세트  1125   7500  NaN

# %% [markdown]
# ### g_index라는 변수에 kcal가 500미만이고, price가 5000 이하인 인덱스를 저장하기 + 인덱스가 g_index인 '만족도' 값을 모두 5로 만들기 (loc, iloc 명령 중 선택하여 사용)

# %%
g_index = df2[(df2['kcal'] <= 500)&(df2['price'] <= 5000)]
for i in g_index.index:
    df2.loc[i, '만족도']=5
df2
# Out:
#             메뉴  kcal  price  만족도
# 0      핫클라쓰 세트  1231   7200  NaN
# 1    마일드클라쓰 세트  1095   6300  NaN
# 2   리아미라클버거 세트   968   7400  NaN
# 3   와규 에디션Ⅱ 세트   892   7600  NaN
# 4      더블X2 세트  1125   7500  NaN
# ..         ...   ...    ...  ...
# 77   아이스 아메리카노    32   2000  5.0
# 78        카페라떼   210   2400  5.0
# 79    아이스 카페라떼    98   2400  5.0
# 80       레몬에이드   151   2500  5.0
# 81      오미자에이드   140   3000  5.0
#
# [82 rows x 4 columns]

# %% [markdown]
# ### s_index라는 변수에 kcal가 500이상, 1000미만인 인덱스를 저장하기 + 인덱스가 s_index인 '만족도' 값을 모두 3로 만들기 (loc, iloc 명령 중 선택하여 사용)

# %%
s_index = df2[(df2['kcal'] >= 500) & (df2['kcal'] < 1000)]
for i in s_index.index:
    df2.loc[i, '만족도']=3
df2
# Out:
#             메뉴  kcal  price  만족도
# 0      핫클라쓰 세트  1231   7200  NaN
# 1    마일드클라쓰 세트  1095   6300  NaN
# 2   리아미라클버거 세트   968   7400  3.0
# 3   와규 에디션Ⅱ 세트   892   7600  3.0
# 4      더블X2 세트  1125   7500  NaN
# ..         ...   ...    ...  ...
# 77   아이스 아메리카노    32   2000  5.0
# 78        카페라떼   210   2400  5.0
# 79    아이스 카페라떼    98   2400  5.0
# 80       레몬에이드   151   2500  5.0
# 81      오미자에이드   140   3000  5.0
#
# [82 rows x 4 columns]

# %% [markdown]
# ### b_index라는 변수에 kcal가 1000이상인 인덱스를 저장하기 + 인덱스가 b_index인 '만족도' 값을 모두 1로 만들기 (loc, iloc 명령 중 선택하여 사용)

# %%
s_index = df2[(df2['kcal'] >= 1000)]
for i in s_index.index:
    df2.loc[i, '만족도']=1
df2
# Out:
#             메뉴  kcal  price  만족도
# 0      핫클라쓰 세트  1231   7200  1.0
# 1    마일드클라쓰 세트  1095   6300  1.0
# 2   리아미라클버거 세트   968   7400  3.0
# 3   와규 에디션Ⅱ 세트   892   7600  3.0
# 4      더블X2 세트  1125   7500  1.0
# ..         ...   ...    ...  ...
# 77   아이스 아메리카노    32   2000  5.0
# 78        카페라떼   210   2400  5.0
# 79    아이스 카페라떼    98   2400  5.0
# 80       레몬에이드   151   2500  5.0
# 81      오미자에이드   140   3000  5.0
#
# [82 rows x 4 columns]

# %% [markdown]
# ### df2의 각각의 칼럼에 총 몇 개의 NaN을 가지고 있는지 한 번에 나타내기

# %%
df.isna().sum()
# Out:
# 메뉴       0
# kcal     0
# price    0
# dtype: int64

# %% [markdown]
# ### df2의 '만족도' 칼럼이 NaN인 행의 데이터 찾기

# %%
df2[df2['만족도'].isnull()]
# Out:
#          메뉴  kcal  price  만족도
# 28  와규 에디션Ⅱ   497   5800  NaN

# %% [markdown]
# ### df2가 갖고 있는 결손 데이터 삭제하기 + 삭제가 잘 되었는지 확인하기

# %%
df2 = df2.dropna()
df.isna().sum()
# Out:
# 메뉴       0
# kcal     0
# price    0
# dtype: int64

# %% [markdown]
# ### df를 'price'가 높은 순서대로 정렬하여 'high_price'라는 새로운 데이터프레임으로 저장하기 + high_price 데이터 프레임의 인덱스를 '메뉴'로 바꾸기 + high_price 상위 7줄 나타내기

# %%
high_price = df2.sort_values(by='price', ascending=False)
high_price.set_index('메뉴', inplace=True)
high_price.head(7)
# Out:
#          kcal  price  만족도
# 메뉴
# 치킨풀팩     2590  18800  1.0
# 순살치킨 풀팩  1477  15900  1.0
# 한우명품팩    1830  15600  1.0
# 한우연인팩    1714  13900  1.0
# 패밀리팩     1712  13600  1.0
# 1인혼닭 세트   801  11500  3.0
# 1인혼닭      581  10000  3.0

# %% [markdown]
# ### matplotlib을 사용하여 시각화하기

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import platform
from matplotlib import font_manager, rc

plt.rcParams['axes.unicode_minus'] = False

#윈도우
path = "c:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname=path).get_name()
rc('font', family=font_name)

#맥
#rc('font', family='AppleGothic')

# %% [markdown]
# ### 시각화 조건
# figure 크기는 (10,10)
#
# plt.scatter을 사용하여 데이터를 점으로 나타내기, x축 값은 df['kcal'], y축 값은 df['price'], 점의 사이즈는 50, 마커 모양은 별모양, 색깔은 초록색
#
# 제목은 '롯데리아 메뉴'
#
# x축 제목은 '칼로리'
#
# y축 제목은 '가격'
#
# y축 범위는 0~20000
#
# high_price 데이터 프레임을 사용하여 가격이 높은 상위 7개 메뉴 글자로 나타내기
#
# 시각화 한 차트를 현재경로(test폴더)에 png 형식으로 저장하기 (파일명: '롯데리아메뉴_학년반번호이름')
# ex) 롯데리아메뉴_3221임은영

# %%
plt.figure(figsize=(10,10))
plt.scatter(high_price['kcal'],high_price['price'], s=50, marker="*", color='g')

plt.title('롯데리아 메뉴')
plt.xlabel('칼로리')
plt.ylabel('가격')
plt.ylim(0,20000)

for i in range(7):
    plt.text(high_price['kcal'][i], high_price['price'][i], high_price.index[i], fontsize=10)

plt.savefig('롯데리아 메뉴_3115정민우.png')
plt.show()
