# %%
import pandas as pd

# %%
import numpy as np

# %%
list = [[1,2,3], [4,5,6]]

df_list = pd.DataFrame(list,columns = ['col1', 'col2', ' col3'])
df_list
# Out:
#    col1  col2   col3
# 0     1     2      3
# 1     4     5      6

# %%
array = np.array(list)
df_arr = df_list = pd.DataFrame(array, columns = ['col1', 'col2', ' col3'])
df_arr
# Out:
#    col1  col2   col3
# 0     1     2      3
# 1     4     5      6

# %%
dict = {'col1' : [1,11], 'col2' : [2,22], 'col3' : [3,33]}
df_dict = pd.DataFrame(dict,index = ['one', 'two'])
df_dict
# Out:
#      col1  col2  col3
# one     1     2     3
# two    11    22    33

# %%
data = {'Name': ['Chulmin','Eunkyung','Jinwoong','Soobeom'], 'Year': [2011,2016,2015,2015], 'Gender' : ['Male','Female','Male','Male']}
data_dict = pd.DataFrame(data,index = ['one','two', 'three','Four'])
data_dict
# Out:
#            Name  Year  Gender
# one     Chulmin  2011    Male
# two    Eunkyung  2016  Female
# three  Jinwoong  2015    Male
# Four    Soobeom  2015    Male

# %%
array = df_dict.values
print('df_dict.values타입 :' , type(array))
print('df_dict.values shape :', array.shape)
print(array)
# Out:
# df_dict.values타입 : <class 'numpy.ndarray'>
# df_dict.values shape : (2, 3)
# [[ 1  2  3]
#  [11 22 33]]

# %%
list = df_dict.values.tolist()
print('df_dict.values.tolist()타입 :', type(list))
print(list)
# Out:
# df_dict.values.tolist()타입 : <class 'list'>
# [[1, 2, 3], [11, 22, 33]]

# %%
dict = df_dict.to_dict('list')
print('df_dict.to_dict()타입 : ', type(dict))
print(dict)
# Out:
# df_dict.to_dict()타입 :  <class 'dict'>
# {'col1': [1, 11], 'col2': [2, 22], 'col3': [3, 33]}

# %%
print(data_dict)
# Out:
#            Name  Year  Gender
# one     Chulmin  2011    Male
# two    Eunkyung  2016  Female
# three  Jinwoong  2015    Male
# Four    Soobeom  2015    Male

# %%
data_dict.Gender
# Out:
# one        Male
# two      Female
# three      Male
# Four       Male
# Name: Gender, dtype: object

# %%
pd.DataFrame(data_dict.Gender)
# Out:
#        Gender
# one      Male
# two    Female
# three    Male
# Four     Male

# %%
data_dict['Gender']
# Out:
# one        Male
# two      Female
# three      Male
# Four       Male
# Name: Gender, dtype: object

# %%
data_dict[['Gender']]
# Out:
#        Gender
# one      Male
# two    Female
# three    Male
# Four     Male

# %%
data_dict[['Name', 'Gender']]
# Out:
#            Name  Gender
# one     Chulmin    Male
# two    Eunkyung  Female
# three  Jinwoong    Male
# Four    Soobeom    Male

# %%
data_dict[1:3]
# Out:
#            Name  Year  Gender
# two    Eunkyung  2016  Female
# three  Jinwoong  2015    Male

# %%
data_df1 = data_dict.copy()
data_df1
# Out:
#            Name  Year  Gender
# one     Chulmin  2011    Male
# two    Eunkyung  2016  Female
# three  Jinwoong  2015    Male
# Four    Soobeom  2015    Male

# %%
data_df_reset = data_df1.reset_index()
data_df_reset
# Out:
#    index      Name  Year  Gender
# 0    one   Chulmin  2011    Male
# 1    two  Eunkyung  2016  Female
# 2  three  Jinwoong  2015    Male
# 3   Four   Soobeom  2015    Male

# %%
data_df_reset = data_df1.reset_index(drop=True)
data_df_reset
# Out:
#        Name  Year  Gender
# 0   Chulmin  2011    Male
# 1  Eunkyung  2016  Female
# 2  Jinwoong  2015    Male
# 3   Soobeom  2015    Male

# %%
data_df_reset = data_df_reset.rename(columns={'index': 'old_index'})
data_df_reset.index = data_df_reset.index +1
data_df_reset
# Out:
#        Name  Year  Gender
# 1   Chulmin  2011    Male
# 2  Eunkyung  2016  Female
# 3  Jinwoong  2015    Male
# 4   Soobeom  2015    Male

# %%
data = {'Name': ['Chulmin','Eunkyung','Jinwoong','Soobeom'], 'Year': [2011,2016,2015,2015], 'Gender' : ['Male','Female','Male','Male']}
data_df = pd.DataFrame(data,index = ['one','two', 'three','Four'])
data_df
# Out:
#            Name  Year  Gender
# one     Chulmin  2011    Male
# two    Eunkyung  2016  Female
# three  Jinwoong  2015    Male
# Four    Soobeom  2015    Male

# %%
data_df2 = data_df.copy()
data_df2
# Out:
#            Name  Year  Gender
# one     Chulmin  2011    Male
# two    Eunkyung  2016  Female
# three  Jinwoong  2015    Male
# Four    Soobeom  2015    Male

# %%
data_df_reset = data_df2.reset_index()
data_df_reset
# Out:
#    index      Name  Year  Gender
# 0    one   Chulmin  2011    Male
# 1    two  Eunkyung  2016  Female
# 2  three  Jinwoong  2015    Male
# 3   Four   Soobeom  2015    Male

# %%
data_df_reset = data_df_reset.rename(columns={'index': 'old_index'})
data_df_reset.index = data_df_reset.index +1
data_df_reset
# Out:
#   old_index      Name  Year  Gender
# 1       one   Chulmin  2011    Male
# 2       two  Eunkyung  2016  Female
# 3     three  Jinwoong  2015    Male
# 4      Four   Soobeom  2015    Male

# %%
data_df2.set_index("Year", inplace=True)
data_df2
# Out:
#           Name  Gender
# Year
# 2011   Chulmin    Male
# 2016  Eunkyung  Female
# 2015  Jinwoong    Male
# 2015   Soobeom    Male

# %%
data_df[['Name', 'Gender']][data_df['Year'] > 2012]
# Out:
#            Name  Gender
# two    Eunkyung  Female
# three  Jinwoong    Male
# Four    Soobeom    Male

# %%
data_df[data_df['Year']>=2012]
# Out:
#            Name  Year  Gender
# two    Eunkyung  2016  Female
# three  Jinwoong  2015    Male
# Four    Soobeom  2015    Male

# %%
data_df[['Name']][data_df['Year'] > 2012][data_df['Gender']=='Male']
# Out:
# C:\Users\fwwfl\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#            Name
# three  Jinwoong
# Four    Soobeom

# %%
data_df.iloc[1, 0]
# Out:
# 'Eunkyung'

# %%
#data_df.iloc['one', 0]

# %%
data_df.iloc[1:3]
# Out:
#            Name  Year  Gender
# two    Eunkyung  2016  Female
# three  Jinwoong  2015    Male

# %%
data_df.iloc[[0, 3], 0:2]
# Out:
#          Name  Year
# one   Chulmin  2011
# Four  Soobeom  2015

# %%
data_df.loc['one','Name']
# Out:
# 'Chulmin'

# %%
data_df_reset.loc[1,'Name']
# Out:
# 'Chulmin'

# %%
data_df_reset
# Out:
#   old_index      Name  Year  Gender
# 1       one   Chulmin  2011    Male
# 2       two  Eunkyung  2016  Female
# 3     three  Jinwoong  2015    Male
# 4      Four   Soobeom  2015    Male

# %%
data_df
# Out:
#            Name  Year  Gender
# one     Chulmin  2011    Male
# two    Eunkyung  2016  Female
# three  Jinwoong  2015    Male
# Four    Soobeom  2015    Male

# %%
data_df_reset.loc[1:2,'Name']
# Out:
# 1     Chulmin
# 2    Eunkyung
# Name: Name, dtype: object

# %%
titanic_df = pd.read_csv('../data/titanic_train.csv', encoding='utf-8')
titanic_df.isna().head(3)
# Out:
#    PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0        False     False   False  False  False  False  False  False   False
# 1        False     False   False  False  False  False  False  False   False
# 2        False     False   False  False  False  False  False  False   False
#
#     Fare  Cabin  Embarked
# 0  False   True     False
# 1  False  False     False
# 2  False   True     False

# %%
titanic_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic_df[titanic_df['Age'].isna()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
titanic_df['Age'][titanic_df['Age'].isna()] = titanic_df['Age'].mean()
titanic_df
# Out:
# C:\Users\fwwfl\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# ...

# %%
titanic_df[['Age', 'Fare']].mean()
# Out:
# Age     29.699118
# Fare    32.204208
# dtype: float64

# %%
titanic_df['Embarked'][titanic_df['Embarked'].isna()] = 'N'
titanic_df
# Out:
# C:\Users\fwwfl\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# ...

# %%
titanic_df_groupby = titanic_df.groupby(by='Pclass').count()
titanic_df_groupby.head()
# Out:
#         PassengerId  Survived  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Pclass
# 1               216       216   216  216  216    216    216     216   216
# 2               184       184   184  184  184    184    184     184   184
# 3               491       491   491  491  491    491    491     491   491
#
#         Cabin  Embarked
# Pclass
# 1         176       216
# 2          16       184
# 3          12       491

# %%
titanic_df_groupby = titanic_df.groupby(by='Pclass')[['PassengerId', 'Survived']].count()
titanic_df_groupby.head()
# Out:
#         PassengerId  Survived
# Pclass
# 1               216       216
# 2               184       184
# 3               491       491

# %%
titanic_df_groupby = titanic_df.groupby(by='Pclass')[['Age']].agg([min, max])
titanic_df_groupby.head()
# Out:
#          Age
#          min   max
# Pclass
# 1       0.92  80.0
# 2       0.67  70.0
# 3       0.42  74.0

# %%
titanic_df['Name_len'] = titanic_df['Name'].apply(lambda x: len(x))
titanic_df[['Name', 'Name_len']].head()
# Out:
#                                                 Name  Name_len
# 0                            Braund, Mr. Owen Harris        23
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...        51
# 2                             Heikkinen, Miss. Laina        22
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)        44
# 4                           Allen, Mr. William Henry        24

# %%
import seaborn as sns
sns.set(style='darkgrid')

tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x='total_bill', y='tip', data=tips, style='smoker', hue='size', palette='terrain')

# %%
import seaborn as sns

tips = sns.load_dataset('tips')

sns.catplot(x='day', y='total_bill', data=tips, kind='box')

# %%
sns.lmplot(data=tips, x='total_bill', y='tip', hue='smoker', markers=['s', '*'])

# %%
sns.relplot(x='total_bill', y='tip', data=tips, style='smoker', hue='size')

# %%
fmri = sns.load_dataset('fmri')
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.relplot(x='timepoint', y='signal', kind='line', data=fmri, hue='region', style='event')

# %%
sns.catplot(x='day', y='total_bill', data=tips)

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind='swarm')

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind='boxen')

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind='bar')

# %%
df = pd.DataFrame(np.random.randn(500, 2), columns=['1', '2'])
df
# Out:
#             1         2
# 0   -0.152351 -1.415385
# 1    1.221632 -0.072871
# 2    0.734956 -0.805205
# 3   -1.593159  0.155189
# 4    0.966010  0.580458
# ..        ...       ...
# 495  1.064418 -0.987882
# 496 -0.438448  0.618751
# 497 -0.081230  0.419580
# 498  0.224447 -0.341847
# 499  1.040440  0.708533
#
# [500 rows x 2 columns]

# %%
sns.relplot(data=df, x='1', y='2')

# %%
sns.jointplot(data=df, x='1', y='2', kind='hex')

# %%
sns.jointplot(data=df, x='1', y='2', kind='kde')

# %%
sns.jointplot(data=df, x='1', y='2', kind='reg')

# %%
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
flights = flights.pivot(index='month', columns='year', values='passengers')
flights.head()
# Out:
# year      1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January    112   115   145   171   196   204   242   284   315   340   360
# February   118   126   150   180   196   188   233   277   301   318   342
# March      132   141   178   193   236   235   267   317   356   362   406
# April      129   135   163   181   235   227   269   313   348   348   396
# May        121   125   172   183   229   234   270   318   355   363   420
#
# year      1960
# month
# January    417
# February   391
# March      419
# April      461
# May        472

# %%
sns.heatmap(flights, annot=True, fmt='d', linewidths=.5)

# %%
sns.set_styles=('tips')
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris, hue='species')

# %%
sns.pairplot(iris, hue='species', vars=['sepal_width', 'sepal_length'])

# %%
sns.pairplot(iris, hue='species', x_vars=['sepal_width', 'sepal_length'], y_vars=['petal_width', 'petal_length'])

# %%
sns.pairplot(iris, kind='reg', size=3)
# Out:
# C:\Users\fwwfl\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)
