# %%
import pandas as pd

# %%
ac = pd.read_csv('../data/ex1.csv',encoding='utf-8')
ac.head()
# Out:
#    relative_time  LinearAccelerometerSensor
# 0              0                   0.459435
# 1             77                   0.199160
# 2            118                   0.168405
# 3            196                   0.042692
# 4            235                   0.037394

# %%
ac.columns
# Out:
# Index(['relative_time', 'LinearAccelerometerSensor'], dtype='object')

# %%
ac.columns[0]
# Out:
# 'relative_time'

# %%
ac.rename(columns={ac.columns[0]:'시간',ac.columns[1]:'선형가속도'},inplace=True)
ac.head()
# Out:
#     시간     선형가속도
# 0    0  0.459435
# 1   77  0.199160
# 2  118  0.168405
# 3  196  0.042692
# 4  235  0.037394

# %%
ac.describe()
# Out:
#                  시간       선형가속도
# count    633.000000  633.000000
# mean   18876.030016    6.920940
# std    10918.205479   12.066849
# min        0.000000    0.037394
# 25%     9433.000000    1.347235
# 50%    18864.000000    3.260228
# 75%    28297.000000    5.453157
# max    37732.000000   67.648040

# %%
ac.sort_values(by='선형가속도',ascending=False).head()
# Out:
#         시간      선형가속도
# 104   6206  67.648040
# 126   7520  66.560340
# 103   6166  64.685824
# 125   7480  64.644366
# 429  25632  64.271857

# %%
ac.sort_values(by='선형가속도',ascending=True).head()
# Out:
#     시간     선형가속도
# 4  235  0.037394
# 3  196  0.042692
# 5  316  0.052932
# 6  355  0.059930
# 7  434  0.066119

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import platform
from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus']=False

if platform.system() == 'Darwin':
    rc('font',family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry')

# %%
plt.plot(ac['시간'],ac['선형가속도'])
plt.show()

# %%
plt.plot(ac['시간'],ac['선형가속도'])
plt.title('선형가속도계')
plt.xlabel('시간')
plt.ylabel('선형가속도')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(ac['시간'],ac['선형가속도'])
plt.title('선형가속도계')
plt.xlabel('시간')
plt.ylabel('선형가속도')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(ac['시간'],ac['선형가속도'])
plt.grid()
plt.title('선형가속도계')
plt.xlabel('시간')
plt.ylabel('선형가속도')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(ac['시간'],ac['선형가속도'],color='green',linestyle='dashed',marker='o')
plt.grid()
plt.title('선형가속도계')
plt.xlabel('시간')
plt.ylabel('선형가속도')
plt.show()
